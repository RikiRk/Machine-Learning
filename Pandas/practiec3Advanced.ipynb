# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head(
)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Name"][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
s = pd.Series(list(df["Name"][2:7]), index= ["a", "b", "c", "d", "e"])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# d                                Moran, Mr. James
# e                         McCarthy, Mr. Timothy J
# dtype: object

# %%
s1 = df["Name"][5:10]

# %%
s1
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# dtype: object

# %%
s.append(s1)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# a                               Heikkinen, Miss. Laina
# b         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                             Allen, Mr. William Henry
# d                                     Moran, Mr. James
# e                              McCarthy, Mr. Timothy J
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
# df.drop("PassengerId")

# %%
df.drop("PassengerId", axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.drop("PassengerId", axis = 1, inplace= True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop(3 ,inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df.set_index('Name',inplace=True)
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.loc['Heikkinen, Miss. Laina']
# Out:
# Survived                   1
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
d = {"key1":[2,3,4,5 ],
     "key2":[4,5,6,7],
     "key3":[2,3,4,5]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
d1 = {"key1":(2,3,4,5 ),
     "key2":(4,5,6,7),
     "key3":(2,3,4,5)}

# %%
pd.DataFrame(d1)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv(r"C:\Users\subha\OneDrive\Desktop\Machinelearning\Machine-Learning\Pandas\taxonomy.csv")

# %%
df1.head(15)
# Out:
#    taxonomy_id                       name parent_id       parent_name
# 0          101                  Emergency       NaN               NaN
# 1       101-01          Disaster Response       101         Emergency
# 2       101-02             Emergency Cash       101         Emergency
# 3    101-02-01          Help Pay for Food    101-02    Emergency Cash
# 4    101-02-02    Help Pay for Healthcare    101-02    Emergency Cash
# 5    101-02-03       Help Pay for Housing    101-02    Emergency Cash
# 6    101-02-04           Help Pay for Gas    101-02    Emergency Cash
# 7    101-02-05        Help Pay for School    101-02    Emergency Cash
# 8    101-02-06     Help Pay for Utilities    101-02    Emergency Cash
# 9       101-03             Emergency Food       101         Emergency
# 10      101-04          Emergency Shelter       101         Emergency
# 11      101-05  Help Find Missing Persons       101         Emergency
# 12      101-06           Immediate Safety       101         Emergency
# 13   101-06-01       Help Escape Violence    101-06  Immediate Safety
# 14   101-06-02               Safe Housing    101-06  Immediate Safety

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("Riki")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      Riki                  Riki
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.groupby("Survived").mean()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\2030998582.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Survived").mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
df.groupby("Sex").sum()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\544993148.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Sex").sum()
#         Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       232     677   7251.00    217    204  13913.5628
# male         109    1379  13919.17    248    136  14727.2865

# %%
df.groupby("Sex").sum()["Fare"]
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\1358974664.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Sex").sum()["Fare"]
# Sex
# female    13913.5628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby("Sex").mean()["Age"]
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\2339759058.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Sex").mean()["Age"]
# Sex
# female    27.888462
# male      30.726645
# Name: Age, dtype: float64

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.groupby("Pclass").mean()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\3573772437.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby("Pclass").sum()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\6622528.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Pclass").sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
df3 = df.groupby("Pclass").mean()
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_9472\372414584.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby("Pclass").mean()

# %%
df3
# Out:
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df3.transpose()
# Out:
# Pclass            1          2          3
# Survived   0.627907   0.472826   0.242363
# Age       38.250919  29.877630  25.140620
# SibSp      0.413953   0.402174   0.615071
# Parch      0.358140   0.380435   0.393075
# Fare      84.299128  20.662183  13.675550

# %%
df3.T
# Out:
# Pclass            1          2          3
# Survived   0.627907   0.472826   0.242363
# Age       38.250919  29.877630  25.140620
# SibSp      0.413953   0.402174   0.615071
# Parch      0.358140   0.380435   0.393075
# Fare      84.299128  20.662183  13.675550

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df11 = df[["Survived",	"Pclass",	"Sex","Age","SibSp"]][0:6]

# %%
df11
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# McCarthy, Mr. Timothy J                                    0       1    male
#
#                                                      Age  SibSp
# Name
# Braund, Mr. Owen Harris                             22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1
# Heikkinen, Miss. Laina                              26.0      0
# Allen, Mr. William Henry                            35.0      0
# Moran, Mr. James                                     NaN      0
# McCarthy, Mr. Timothy J                             54.0      0

# %%
df12 = df[[		"Survived",	"Pclass",	"Sex","Age","SibSp"]][6:12]

# %%
df12
# Out:
#                                                    Survived  Pclass     Sex  \
# Name
# Palsson, Master. Gosta Leonard                            0       3    male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3  female
# Nasser, Mrs. Nicholas (Adele Achem)                       1       2  female
# Sandstrom, Miss. Marguerite Rut                           1       3  female
# Bonnell, Miss. Elizabeth                                  1       1  female
# Saundercock, Mr. William Henry                            0       3    male
#
#                                                     Age  SibSp
# Name
# Palsson, Master. Gosta Leonard                      2.0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0
# Nasser, Mrs. Nicholas (Adele Achem)                14.0      1
# Sandstrom, Miss. Marguerite Rut                     4.0      1
# Bonnell, Miss. Elizabeth                           58.0      0
# Saundercock, Mr. William Henry                     20.0      0

# %%
pd.concat([df11,df12])
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# McCarthy, Mr. Timothy J                                    0       1    male
# Palsson, Master. Gosta Leonard                             0       3    male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)          1       3  female
# Nasser, Mrs. Nicholas (Adele Achem)                        1       2  female
# Sandstrom, Miss. Marguerite Rut                            1       3  female
# Bonnell, Miss. Elizabeth                                   1       1  female
# Saundercock, Mr. William Henry                             0       3    male
#
#                                                      Age  SibSp
# Name
# Braund, Mr. Owen Harris                             22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1
# Heikkinen, Miss. Laina                              26.0      0
# Allen, Mr. William Henry                            35.0      0
# Moran, Mr. James                                     NaN      0
# McCarthy, Mr. Timothy J                             54.0      0
# Palsson, Master. Gosta Leonard                       2.0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   27.0      0
# Nasser, Mrs. Nicholas (Adele Achem)                 14.0      1
# Sandstrom, Miss. Marguerite Rut                      4.0      1
# Bonnell, Miss. Elizabeth                            58.0      0
# Saundercock, Mr. William Henry                      20.0      0

# %%
df5 = pd.concat([df11,df12],axis=1)

# %%
df5
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                  0.0     3.0    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1.0     1.0  female
# Heikkinen, Miss. Laina                                   1.0     3.0  female
# Allen, Mr. William Henry                                 0.0     3.0    male
# Moran, Mr. James                                         0.0     3.0    male
# McCarthy, Mr. Timothy J                                  0.0     1.0    male
# Palsson, Master. Gosta Leonard                           NaN     NaN     NaN
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        NaN     NaN     NaN
# Nasser, Mrs. Nicholas (Adele Achem)                      NaN     NaN     NaN
# Sandstrom, Miss. Marguerite Rut                          NaN     NaN     NaN
# Bonnell, Miss. Elizabeth                                 NaN     NaN     NaN
# Saundercock, Mr. William Henry                           NaN     NaN     NaN
#
#                                                      Age  SibSp  Survived  \
# Name
# Braund, Mr. Owen Harris                             22.0    1.0       NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0    1.0       NaN
# Heikkinen, Miss. Laina                              26.0    0.0       NaN
# Allen, Mr. William Henry                            35.0    0.0       NaN
# Moran, Mr. James                                     NaN    0.0       NaN
# McCarthy, Mr. Timothy J                             54.0    0.0       NaN
# Palsson, Master. Gosta Leonard                       NaN    NaN       0.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    NaN    NaN       1.0
# Nasser, Mrs. Nicholas (Adele Achem)                  NaN    NaN       1.0
# Sandstrom, Miss. Marguerite Rut                      NaN    NaN       1.0
# Bonnell, Miss. Elizabeth                             NaN    NaN       1.0
# Saundercock, Mr. William Henry                       NaN    NaN       0.0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                NaN     NaN   NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     NaN     NaN   NaN
# Heikkinen, Miss. Laina                                 NaN     NaN   NaN
# Allen, Mr. William Henry                               NaN     NaN   NaN
# Moran, Mr. James                                       NaN     NaN   NaN
# McCarthy, Mr. Timothy J                                NaN     NaN   NaN
# Palsson, Master. Gosta Leonard                         3.0    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      3.0  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                    2.0  female  14.0
# Sandstrom, Miss. Marguerite Rut                        3.0  female   4.0
# Bonnell, Miss. Elizabeth                               1.0  female  58.0
# Saundercock, Mr. William Henry                         3.0    male  20.0
#
#                                                     SibSp
# Name
# Braund, Mr. Owen Harris                               NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    NaN
# Heikkinen, Miss. Laina                                NaN
# Allen, Mr. William Henry                              NaN
# Moran, Mr. James                                      NaN
# McCarthy, Mr. Timothy J                               NaN
# Palsson, Master. Gosta Leonard                        3.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     0.0
# Nasser, Mrs. Nicholas (Adele Achem)                   1.0
# Sandstrom, Miss. Marguerite Rut                       1.0
# Bonnell, Miss. Elizabeth                              0.0
# Saundercock, Mr. William Henry                        0.0

# %%
df6 = pd.concat([df11,df12])
df6
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# McCarthy, Mr. Timothy J                                    0       1    male
# Palsson, Master. Gosta Leonard                             0       3    male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)          1       3  female
# Nasser, Mrs. Nicholas (Adele Achem)                        1       2  female
# Sandstrom, Miss. Marguerite Rut                            1       3  female
# Bonnell, Miss. Elizabeth                                   1       1  female
# Saundercock, Mr. William Henry                             0       3    male
#
#                                                      Age  SibSp
# Name
# Braund, Mr. Owen Harris                             22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1
# Heikkinen, Miss. Laina                              26.0      0
# Allen, Mr. William Henry                            35.0      0
# Moran, Mr. James                                     NaN      0
# McCarthy, Mr. Timothy J                             54.0      0
# Palsson, Master. Gosta Leonard                       2.0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   27.0      0
# Nasser, Mrs. Nicholas (Adele Achem)                 14.0      1
# Sandstrom, Miss. Marguerite Rut                      4.0      1
# Bonnell, Miss. Elizabeth                            58.0      0
# Saundercock, Mr. William Henry                      20.0      0

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]
})

# %%
data2 = pd.DataFrame({'key1':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(data2,data1)
# Out:
#    key1  key4  key5  key2  key3
# 0     1    56     3     4     3
# 1     2     5    56     5     4
# 2     6     7     6     8     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %% [markdown]
# Here only common number is printed and unique number got emitted

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
pd.merge(data1,data2,how = 'inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(data1,data2,how = 'outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# 21       6     8     6       2     5    56
# 22       6     8     6      45     6     5
# 23       6     8     6       6     7     6
# 24       6     8     6      67     8     6

# %%
pd.merge(data1,data2,how = 'left' , left_on='key2' , right_on= 'key4' )
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                     index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({'key11':[1,2,4,5,6],
                      'key22':[4,5,6,7,8],
                      'key33':[3,4,5,6,6]
},index=['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      4      6      5
# i   NaN   NaN   NaN      5      7      6
# j   NaN   NaN   NaN      6      8      6

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# 21     6     8     6      2      5      4
# 22     6     8     6      4      6      5
# 23     6     8     6      5      7      6
# 24     6     8     6      6      8      6

# %%
 df["Fare_inr"] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
#
#                                                    Cabin Embarked  Fare_inr
# Name
# Braund, Mr. Owen Harris                              NaN        S   580.000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C  5702.664
# Heikkinen, Miss. Laina                               NaN        S   634.000
# Allen, Mr. William Henry                             NaN        S   644.000
# Moran, Mr. James                                     NaN        Q   676.664

# %%
def inr_con(x):
    return x*80

df["Fare_inr"] = df['Fare'].apply(inr_con)

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
#
#                                                    Cabin Embarked  Fare_inr
# Name
# Braund, Mr. Owen Harris                              NaN        S   580.000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C  5702.664
# Heikkinen, Miss. Laina                               NaN        S   634.000
# Allen, Mr. William Henry                             NaN        S   644.000
# Moran, Mr. James                                     NaN        Q   676.664

# %%
def create_flag(x):
    if x< 10 :
        return "cheap"
    elif x >= 10 and x < 20 :
        return  "mid"
    else :
        return "high"

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
#
#                                                    Cabin Embarked  Fare_inr
# Name
# Braund, Mr. Owen Harris                              NaN        S   580.000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C  5702.664
# Heikkinen, Miss. Laina                               NaN        S   634.000
# Allen, Mr. William Henry                             NaN        S   644.000
# Moran, Mr. James                                     NaN        Q   676.664

# %%
df['Flag_fare'] = df["Fare"].apply(create_flag)

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
#
#                                                    Cabin Embarked  Fare_inr  \
# Name
# Braund, Mr. Owen Harris                              NaN        S   580.000
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C  5702.664
# Heikkinen, Miss. Laina                               NaN        S   634.000
# Allen, Mr. William Henry                             NaN        S   644.000
# Moran, Mr. James                                     NaN        Q   676.664
#
#                                                    Flag_fare
# Name
# Braund, Mr. Owen Harris                                cheap
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      high
# Heikkinen, Miss. Laina                                 cheap
# Allen, Mr. William Henry                               cheap
# Moran, Mr. James                                       cheap
